# %% [markdown]
# <a href="https://colab.research.google.com/github/Iciboy23/Dokumen-Penting-Negara/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/EPL woman - matches NEW.csv')

# %%
data
# Out:
#      Order        Date   Time            Comp         Round  Day Venue Result  \
# 0        0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D
# 1        1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W
# 2        2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W
# 3        3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W
# 4        4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W
# ..     ...         ...    ...             ...           ...  ...   ...    ...
# 451     19  2023-12-26  15:00  Premier League  Matchweek 19  Tue  Home      L
# 452     20  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Away      L
# 453     22  2024-01-21  14:00  Premier League  Matchweek 21  Sun  Home      D
# 454     24  2024-01-30  20:00  Premier League  Matchweek 22  Tue  Away      L
# 455     25  2024-02-03  17:30  Premier League  Matchweek 23  Sat  Home      L
#
# ...

# %%
data.head()
# Out:
#    Order        Date   Time            Comp        Round  Day Venue Result  \
# 0      0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D
# 1      1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W
# 2      2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W
# 3      3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W
# 4      4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W
#
#     GF   GA  ...    Sh  SoT  Dist   FK  PK PKatt Season       Team longitude  \
# 0  1.0  1.0  ...  13.0  1.0  17.8  0.0   0     0   2024  Liverpool   -29.886
# 1  3.0  1.0  ...  25.0  9.0  16.8  1.0   0     1   2024  Liverpool   -22.426
# 2  2.0  1.0  ...   9.0  4.0  17.2  1.0   0     0   2024  Liverpool    -1.278
# 3  3.0  0.0  ...  17.0  4.0  14.7  0.0   0     0   2024  Liverpool   -18.904
# 4  3.0  1.0  ...  16.0  5.0  15.8  0.0   0     0   2024  Liverpool    -1.372
#
#    latitude
# 0   534.084
# 1   534.808
# ...

# %%
print(data.dtypes)
# Out:
# Order             int64
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF              float64
# GA              float64
# Opponent         object
# xG              float64
# xGA             float64
# Poss            float64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Sh              float64
# SoT             float64
# Dist            float64
# FK              float64
# PK                int64
# PKatt             int64
# Season            int64
# Team             object
# longitude       float64
# latitude        float64
# dtype: object

# %%
datanovenue = data.drop(data.columns[6],axis=1)

# %%
datanovenue
# Out:
#      Order        Date   Time            Comp         Round  Day Result   GF  \
# 0        0  2023-08-13  16:30  Premier League   Matchweek 1  Sun      D  1.0
# 1        1  2023-08-19  15:00  Premier League   Matchweek 2  Sat      W  3.0
# 2        2  2023-08-27  16:30  Premier League   Matchweek 3  Sun      W  2.0
# 3        3  2023-09-03  14:00  Premier League   Matchweek 4  Sun      W  3.0
# 4        4  2023-09-16  12:30  Premier League   Matchweek 5  Sat      W  3.0
# ..     ...         ...    ...             ...           ...  ...    ...  ...
# 451     19  2023-12-26  15:00  Premier League  Matchweek 19  Tue      L  2.0
# 452     20  2023-12-30  15:00  Premier League  Matchweek 20  Sat      L  0.0
# 453     22  2024-01-21  14:00  Premier League  Matchweek 21  Sun      D  2.0
# 454     24  2024-01-30  20:00  Premier League  Matchweek 22  Tue      L  2.0
# 455     25  2024-02-03  17:30  Premier League  Matchweek 23  Sat      L  0.0
#
# ...

# %%
data.describe()
# Out:
#             Order          GF          GA          xG         xGA        Poss  \
# count  456.000000  456.000000  456.000000  456.000000  456.000000  456.000000
# mean    14.263158    1.600877    1.600877    1.526535    1.526535   50.000000
# std      8.943095    1.305407    1.305407    0.871514    0.871514   13.771766
# min      0.000000    0.000000    0.000000    0.000000    0.000000   20.000000
# 25%      6.000000    1.000000    1.000000    0.900000    0.900000   39.000000
# 50%     14.000000    1.000000    1.000000    1.300000    1.300000   50.000000
# 75%     21.000000    2.000000    2.000000    2.100000    2.100000   61.000000
# max     35.000000    8.000000    8.000000    7.000000    7.000000   80.000000
#
#          Attendance          Sh         SoT        Dist          FK  \
# count    456.000000  456.000000  456.000000  456.000000  456.000000
# mean   38513.447368   13.269737    4.493421   16.723246    0.364035
# ...

# %%
Corr = data.corr()
# Out:
# <ipython-input-22-2b6e1793cdf5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Corr = data.corr()

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Time', y='Result', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c0196be5-841d-47ed-a19d-1a1bbc606a99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0196be5-841d-47ed-a19d-1a1bbc606a99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "epl"
# Out:
# ...
# ref                                                           title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# irkaal/english-premier-league-results                         English Premier League (EPL) Results              595KB  2022-04-11 01:51:51           6773        148  1.0
# thefc17/epl-results-19932018                                  EPL Results 1993-2018                              73KB  2018-07-15 14:10:49           6426        153  0.7647059
# rajatrc1705/english-premier-league202021                      English Premier League(2020-21)                    16KB  2021-06-03 15:44:41           7527        136  0.9411765
# ...

# %%
# !kaggle datasets download irkaal/english-premier-league-results
# Out:
# ...
# 100% 595k/595k [00:00<00:00, 1.04MB/s]
# 100% 595k/595k [00:00<00:00, 1.04MB/s]

# %% [markdown]
# !unzip /content/english-premier-league-results.zip
